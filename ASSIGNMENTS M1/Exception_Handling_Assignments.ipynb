# %% [markdown]
# <a href="https://colab.research.google.com/github/nafis2004/Wipro_TalentNext-DS_261330047-/blob/main/ASSIGNMENTS%20M1/Exception_Handling_Assignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Division with Exception Handling

# %%
try:
    num1 = int(input("Enter first number: "))
    num2 = int(input("Enter second number: "))

    result = num1 / num2
    print("Result:", result)

except ZeroDivisionError:
    print("Error: Cannot divide by zero")

except ValueError:
    print("Error: Please enter valid numbers")
# Out:
# Enter first number: 9
# Enter second number: 0
# Error: Cannot divide by zero

# %% [markdown]
# 2.  Prime Number Check with Exception Handling

# %%
try:
    num = int(input("Enter a number: "))

    if num < 2:
        print("Not Prime")
    else:
        prime = True
        for i in range(2, num):
            if num % i == 0:
                prime = False
                break

        if prime:
            print("Prime")
        else:
            print("Not Prime")

except ValueError:
    print("Error: Invalid input. Enter only numbers")
# Out:
# Enter a number: p
# Error: Invalid input. Enter only numbers

# %% [markdown]
# 3.  Open File and Print Content in Title Case

# %% [markdown]
# Create a sample file

# %%
with open("sample.txt", "w") as file:
    file.write("hello world\npython programming")

# %%
try:
    filename = input("Enter file name: ")

    with open(filename, "r") as file:
        content = file.read()

    print(content.title())

except FileNotFoundError:
    print("Error: File not found")
# Out:
# Enter file name: sample
# Error: File not found

# %% [markdown]
# 4.  Check Positive or Negative using Index

# %%
numbers = [10, -5, 7, -8, 12, -15, 20, -25, 30, -35]

try:
    index = int(input("Enter index (0-9): "))

    num = numbers[index]

    if num > 0:
        print(num, "is Positive")
    else:
        print(num, "is Negative")

except IndexError:
    print("Error: Invalid index")

except ValueError:
    print("Error: Enter a valid number")
# Out:
# Enter index (0-9): -34
# Error: Invalid index
