# %% [markdown]
# <a href="https://colab.research.google.com/github/nafis2004/Wipro_TalentNext-DS_261330047-/blob/main/MINI-PROJECT/Functions_Modules_Packages_Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project1. Sort the Colors

# %%
def sort_colors(colors):
    color_list = colors.split("-")

    color_list.sort()

    result = "-".join(color_list)

    return result

colors = input("Enter colors separated by hyphen: ")

print(sort_colors(colors))
# Out:
# Enter colors separated by hyphen: green-red-yellow-black-white
# black-green-red-white-yellow

# %% [markdown]
# Project2. Playing with Names

# %%
# %%writefile mymodule.py

# Function to check palindrome
def ispalindrome(name):
    if name == name[::-1]:
        return "Yes it is a palindrome."
    else:
        return "No it is not a palindrome."


# Function to count vowels
def count_the_vowels(name):
    vowels = "aeiouAEIOU"
    count = 0

    for ch in name:
        if ch in vowels:
            count += 1
    return count


# Function to count frequency of letters
def frequency_of_letters(name):
    freq = {}

    for ch in name:
        if ch != " ":
            if ch in freq:
                freq[ch] += 1
            else:
                freq[ch] = 1

    return freq
# Out:
# Writing mymodule.py

# %%
import mymodule

# %%
name = input("Enter your name: ")

print(mymodule.ispalindrome(name))
print("No of vowels:", mymodule.count_the_vowels(name))
print("Frequency of letters:", mymodule.frequency_of_letters(name))
# Out:
# Enter your name: marcel bentok tanaka
# No it is not a palindrome.
# No of vowels: 7
# Frequency of letters: {'m': 1, 'a': 4, 'r': 1, 'c': 1, 'e': 2, 'l': 1, 'b': 1, 'n': 2, 't': 2, 'o': 1, 'k': 2}
